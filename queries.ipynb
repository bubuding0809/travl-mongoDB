# %%
import os
import utils
from pprint import pprint
from datetime import datetime, timezone

connection_string = os.environ.get('DATABASE_URL')
db = utils.load_db(connection_string, 'travl_db')
# Out:
# Connected to MongoDB

# %% [markdown]
# ## Query 0 - Full text search feature demostration on City collection

# %%
cursor = db.City.find(
    {'$text': {'$search': 'Boston'}}, 
    {'score': {'$meta': 'textScore'}},
).sort([('score', {'$meta': 'textScore'})])

for idx, doc in enumerate(cursor):
    print(str(idx) + ": ", end="")
    pprint(doc, indent=2)
    print()
# Out:
# 0: { '_id': '1840000455',
#   'capital': 'admin',
#   'cityName': 'Boston',
#   'country': { 'alpha3': 'USA',
#                'countryName': 'United States',
#                'currency': {'currencyName': 'US dollar', 'isoCode': 'USD'},
#                'region': 'Americas'},
#   'location': {'coordinates': [-71.0846, 42.3188], 'type': 'Point'},
#   'population': 4688346,
#   'score': 2.2}
#
# 1: { '_id': '1840023297',
#   'capital': None,
#   'cityName': 'Boston',
#   'country': { 'alpha3': 'USA',
#                'countryName': 'United States',
#                'currency': {'currencyName': 'US dollar', 'isoCode': 'USD'},
#                'region': 'Americas'},
#   'location': {'coordinates': [-78.7555, 42.6528], 'type': 'Point'},
#   'population': 8042,
#   'score': 2.2}
#
# 2: { '_id': '1608800917',
#   'capital': None,
#   'cityName': 'Boston',
#   'country': { 'alpha3': 'PHL',
#                'countryName': 'Philippines',
#                'currency': { 'currencyName': 'Philippine peso',
#                              'isoCode': 'PHP'},
#                'region': 'Asia'},
#   'location': {'coordinates': [126.367, 7.8667], 'type': 'Point'},
#   'population': 14618,
#   'score': 2.2}
#
# 3: { '_id': '1840055220',
#   'capital': None,
#   'cityName': 'New Boston',
#   'country': { 'alpha3': 'USA',
#                'countryName': 'United States',
#                'currency': {'currencyName': 'US dollar', 'isoCode': 'USD'},
#                'region': 'Americas'},
#   'location': {'coordinates': [-71.686, 42.9774], 'type': 'Point'},
#   'population': 5711,
#   'score': 1.5}
#
# 4: { '_id': '1840037461',
#   'capital': None,
#   'cityName': 'South Boston',
#   'country': { 'alpha3': 'USA',
#                'countryName': 'United States',
#                'currency': {'currencyName': 'US dollar', 'isoCode': 'USD'},
#                'region': 'Americas'},
#   'location': {'coordinates': [-78.9135, 36.7132], 'type': 'Point'},
#   'population': 7740,
#   'score': 1.5}

# %% [markdown]
# ## Query 1 - Find all hospitals and its name, address and phone number within 50Km of the Beijing China. (_id of Bejing is 1156228865.)

# %%
sourceLong, sourceLat = db.City.find_one({'_id': '1156228865'})['location']['coordinates']
cursor = db.Hospital.aggregate([
    {'$geoNear': {
      'near': {'type': 'Point', 'coordinates': [sourceLong, sourceLat]},
      'distanceField': 'distance.calculated',
      'maxDistance': 50 * 1000,
      'spherical': True
    }}, {
      '$project': {
        '_id': 0, 'hospitalName': 1, 'address': 1, 'phone': 1, 'distance.calculated': 1
      }
    }, {'$sort': {'distance.calculated': 1}}
])

for idx, doc in enumerate(cursor):
    print(str(idx) + ": ", end="")
    pprint(doc, indent=2)
    print()
# Out:
# 0: { 'address': 'No.9 Jiuxianqiaobei road,Beijing',
#   'distance': {'calculated': 88.24937500451185},
#   'hospitalName': 'Beijing Oasis International Hospital',
#   'phone': '400-876-2747'}
#
# 1: { 'address': 'F5, Beijing New World Shopping Mall,No.3  Chong Wen Men Wai St., '
#              'Beijing',
#   'distance': {'calculated': 1194.300285593439},
#   'hospitalName': 'Eaton Medical Group',
#   'phone': '010-67085075'}
#
# 2: { 'address': 'Beijing Puhua International Hospital,No 12,Tiantan '
#              'Nanli,Chongwen District,Beijing',
#   'distance': {'calculated': 2428.253316162003},
#   'hospitalName': 'Beijing Puhua International Hospital',
#   'phone': '010-67035566'}
#
# 3: { 'address': '1F Building D,Yonggui Center,No.45 Guang Qu Men Nei St., '
#              'Dongcheng District,Beijing',
#   'distance': {'calculated': 3090.8062267216087},
#   'hospitalName': 'Gushengtang Yonggui TCM Clinic',
#   'phone': '010-67101127'}
#
# 4: { 'address': 'No. 7 Ritan East Rd, Chaoyang District, Beijing',
#   'distance': {'calculated': 3518.406681975031},
#   'hospitalName': 'Beijing Bayley & Jackson Medical Center',
#   'phone': '010-85629998'}
#
# 5: { 'address': 'No.6 Rufuli, South Caishikou Street, Xicheng District, Beijing',
#   'distance': {'calculated': 3938.4267580873097},
#   'hospitalName': 'Beijing Jiangong Hospital',
#   'phone': '010-63532299'}
#
# 6: { 'address': 'NB210, China World Shopping Mall, No.1 Jian Guo Men Wai Ave, '
#              'Chaoyang District, Beijing',
#   'distance': {'calculated': 4313.251175509212},
#   'hospitalName': 'SDM Dental_China World Trade Center Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 7: { 'address': 'Rm 4-7, 2/F, Beijing Century Prosperty Center, No.5 Yard, '
#              'Guanghua Road, Chaoyang District, Beijing',
#   'distance': {'calculated': 4439.135575575423},
#   'hospitalName': 'Arrail Dental - CBD Clinic',
#   'phone': '010-85875338'}
#
# 8: { 'address': 'Lvl 3 Kerry Center Shopping Mall, 1 Guanghua Rd Chaoyang '
#              'District Beijing',
#   'distance': {'calculated': 4585.8547745369315},
#   'hospitalName': 'Vista Clinic',
#   'phone': '010-85296618'}
#
# 9: { 'address': '1F4F5F,Panjiayuan Plaza No.12 Panjiayuan Nanli,Chaoyang '
#              'District,Beijing',
#   'distance': {'calculated': 4785.3916683746775},
#   'hospitalName': 'Beijing Aier-Intech Eye Hospital',
#   'phone': '010-67715558'}
#
# 10: { 'address': 'No.56 Nanlishi Road, Xicheng District,Beijing',
#   'distance': {'calculated': 4859.015620336098},
#   'hospitalName': "New Century International Children's Hospital",
#   'phone': '010-68025588'}
#
# 11: { 'address': 'No.54,Wusheng North Rd,East Third Ring,Chaoyang District,Beijing',
#   'distance': {'calculated': 4961.063712264348},
#   'hospitalName': 'Beijing Puhua  International Clinic',
#   'phone': '010-67035566'}
#
# 12: { 'address': '1st Floor, Hengxiang Plaza, Tuanjiehu, Chaoyang District, '
#              'Beijing',
#   'distance': {'calculated': 5339.673220479187},
#   'hospitalName': 'Flower Medical Center of Beijing',
#   'phone': '010-85977336'}
#
# 13: { 'address': '6D/E C Building ,Dongfangyinzuo, No.48 Dongzhimenwai '
#              'St,Dongcheng District, Beijing',
#   'distance': {'calculated': 5486.603611988897},
#   'hospitalName': 'Beijng Kanwa Dental',
#   'phone': '010-84477859'}
#
# 14: { 'address': 'No. 24, Xi Da Wang Rd, Chaoyang District, Beijing',
#   'distance': {'calculated': 6049.762797635916},
#   'hospitalName': "Global Care Women & Children's Hospital",
#   'phone': '010-87769899'}
#
# 15: { 'address': 'Rm 101, No.16 Building, China Central Place, No.89 Jianguo Road, '
#              'Chaoyang District, Beijing',
#   'distance': {'calculated': 6384.439898743305},
#   'hospitalName': 'Arrail Dental - Central-P Clinic',
#   'phone': '010-85888550/60/70'}
#
# 16: { 'address': 'Room102. No.16 Business Building China Central Place,89 Jianguo '
#              'Rd Chaoyang District,Beijing',
#   'distance': {'calculated': 6384.439898743305},
#   'hospitalName': 'Orient Care Clinic',
#   'phone': '010-65981887'}
#
# 17: { 'address': 'Room S106, Lufthansa Center Office BuildingNo50. Liangmaqiao '
#              'Rd.Chaoyang District,Beijing',
#   'distance': {'calculated': 6940.509483230772},
#   'hospitalName': 'Beijing International Medical Center',
#   'phone': '010-64651561'}
#
# 18: { 'address': 'Suite 118, 1st Floor, Towrcrest Plaza, No.3 West Maizidian Road, '
#              'Chaoyang District, Beijing',
#   'distance': {'calculated': 7065.67721408497},
#   'hospitalName': "King's Dental",
#   'phone': '010-84580388'}
#
# 19: { 'address': '1/F, Somerset Fortune Garden, No.46 Liangmaqiao Road, Chaoyang '
#              'District, Beijing',
#   'distance': {'calculated': 7365.955620375946},
#   'hospitalName': 'Arrail Dental - Somerset Clinic',
#   'phone': '010-84401926'}
#
# 20: { 'address': 'FC222, 21st Century Hotel, No.40 Liang Ma Qiao Rd., Chaoyang '
#              'District, Beijing',
#   'distance': {'calculated': 7726.392192211987},
#   'hospitalName': 'SDM Dental_21st Century Hotel Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 21: { 'address': '21st Century Plaza F1-F2,Liangmaqiao Rd No.40,Chaoyang '
#              'District,Beijing',
#   'distance': {'calculated': 7949.681686470962},
#   'hospitalName': 'Beijing 21st Century Hospital',
#   'phone': '010-84446168'}
#
# 22: { 'address': 'No. 218, Xiaoguan Beili, Chaoyang District, Beijing',
#   'distance': {'calculated': 9338.995013290538},
#   'hospitalName': 'Beijing American-Sino OB/GYN Hospital',
#   'phone': '010-64968888'}
#
# 23: { 'address': 'No.9 Fangyuan West Rd,Chaoyang District,Beijing',
#   'distance': {'calculated': 10065.17445231293},
#   'hospitalName': "AMCARE Women's& Children's Hospital",
#   'phone': '010-64342399'}
#
# 24: { 'address': 'No.2 Jiangtai Rd, Chaoyang District_Beijing',
#   'distance': {'calculated': 10335.574372144818},
#   'hospitalName': 'Beijing United Family Hospital and Clinics',
#   'phone': '010-59277000'}
#
# 25: { 'address': 'No.9-11 Jiangtaixi Rd,Chaoyang District, Beijing',
#   'distance': {'calculated': 10335.574372144818},
#   'hospitalName': 'Beijing United Family New Hope Oncology Center',
#   'phone': '010-59277008'}
#
# 26: { 'address': 'Rm 201, the Exchange-Beijing, No.118 Yi Jianguo Road, Chaoyang '
#              'District, Beijing',
#   'distance': {'calculated': 11553.298217628637},
#   'hospitalName': 'Arrail Dental - Exchange Clinic',
#   'phone': '010-65675670'}
#
# 27: { 'address': 'No.1 Beiyuan Road, Chaoyang District, Beijing',
#   'distance': {'calculated': 11997.343332492219},
#   'hospitalName': "Mary's Orthopedic Hospital Beijing",
#   'phone': '010-64479999'}
#
# 28: { 'address': 'No.2 Xiaoguan Beili, Beiyuan Rd, Chaoyang District,Beijing',
#   'distance': {'calculated': 11997.343332492219},
#   'hospitalName': "HarMoniCare Women & Children's Hospital",
#   'phone': '010-64990000'}
#
# 29: { 'address': 'Room 106, Building 11, No.22 Yuan Da Rd., Haidian District, '
#              'Beijing',
#   'distance': {'calculated': 12128.943542072519},
#   'hospitalName': 'SDM Dental-Yuan Da Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 30: { 'address': 'F-D186B, Sunshine Plaza 68 Anli Rd., Chaoyang District, Beijing',
#   'distance': {'calculated': 13091.374214416062},
#   'hospitalName': 'SDM Dental_Sunshine Plaza Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 31: { 'address': 'Rm 308, Tower A, Raycom Info Tech Park, No.2 Science Institute '
#              'South Road, Haidian District, Beijing',
#   'distance': {'calculated': 13302.20116234151},
#   'hospitalName': 'Arrail Dental - Raycom Clinic',
#   'phone': '010-82861956'}
#
# 32: { 'address': 'No.1 Xinjiekouwai Street, Haidian District, Beijing',
#   'distance': {'calculated': 13302.20116234151},
#   'hospitalName': 'Baodao Healthcare',
#   'phone': '010-62006666'}
#
# 33: { 'address': 'Rm 208, Tower A, CITIC Building, No.19 Jianguomenwai Avenue, '
#              'Chaoyang District, Beijing',
#   'distance': {'calculated': 13606.960368272761},
#   'hospitalName': 'Arrail Dental - CITIC Clinic',
#   'phone': '010-65006473'}
#
# 34: { 'address': 'No.19 Fushi Rd Haidian District,Beijing',
#   'distance': {'calculated': 17991.596968576498},
#   'hospitalName': 'Beijing Dcn Orthopaedic Hospital',
#   'phone': '010-52713366'}
#
# 35: { 'address': 'LB107, No.99 Euro Plaza, Yu Xiang Rd, Shunyi District, Beijing',
#   'distance': {'calculated': 21712.322569431177},
#   'hospitalName': 'SDM Dental-Euro Plaza Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 36: { 'address': 'LB107, No.99 Euro Plaza, Yu Xiang Rd, Shunyi District, Beijing',
#   'distance': {'calculated': 21712.322569431177},
#   'hospitalName': 'SDM Dental-Euro Plaza Clinic',
#   'phone': '010-59772486/88/89/90'}
#
# 37: { 'address': 'Pinnacle Plaza, Unit, No.819, Tian Zhu Real Estate Zone, Shunyi '
#              'District,Beijing',
#   'distance': {'calculated': 22412.038874702266},
#   'hospitalName': 'Beijing United Family Dental Shunyi Clinic',
#   'phone': '010-59277001'}
#
# 38: { 'address': 'Rm104,Building 31, Pinnacle Avenue, TianZhu Town, Shunyi '
#              'District, Beijing',
#   'distance': {'calculated': 22412.038874702266},
#   'hospitalName': 'Arrail Dental - Shunyi Ronghe Clinic',
#   'phone': '010-84167988'}
#
# 39: { 'address': 'Pinnacle Plaza, Unit No.818, Tian Zhu Real Estate Zone, Shunyi '
#              'District,Beijing',
#   'distance': {'calculated': 22412.038874702266},
#   'hospitalName': 'Beijing United Family Shunyi Clinic',
#   'phone': '010-59277000'}
#
# 40: { 'address': 'No.15 YanShan Yingfeng Street,FangShan District,Beijing',
#   'distance': {'calculated': 43513.195212572056},
#   'hospitalName': 'Beijing Yan Hua Hospital',
#   'phone': '010-81339505'}

# %% [markdown]
# ## Query 2 - Find the month with the highest new daily average Covid-19 cases in the destination country (_id of Singapore is SGP)

# %%
cursor = db.Country.aggregate([
    {'$match': {'_id': 'SGP'},},
    {'$unwind': {'path': '$covidCases'}},
    {'$replaceRoot': {'newRoot': '$covidCases'}},
    {'$project': {
      'year': {'$year': '$date'},
      'month': {'$month': '$date'},
      'newCases': 1,
    }},
    {'$match': {'year': 2022}},
    {'$group': {'_id': '$month', 'dailyAverageNewCases': {'$avg': '$newCases'}}},
    {'$sort': {'dailyAverageNewCases': -1}},
    {'$limit': 1},
])

for idx, doc in enumerate(cursor):
    print(str(idx) + ": ", end="")
    pprint(doc, indent=2)
    print()
# Out:
# 0: {'_id': 2, 'dailyAverageNewCases': 13271.892857142857}

# %% [markdown]
# # Query 3 - Find the latest exchange rate between SGD to THB

# %%
cursor = db.Forex.find(
  {'currencyBase.isoCode': 'SGD', 'currencyAgainst.isoCode': 'THB'},
  {'_id': 0, 'rate': 1, 'date': 1}
).sort([('date', -1)]).limit(1)

for idx, doc in enumerate(cursor):
    print(str(idx) + ": ", end="")
    pprint(doc, indent=2)
    print()
# Out:
# 0: {'date': datetime.datetime(2022, 10, 29, 0, 0), 'rate': 26.8978}

# %% [markdown]
# ## Query 4 - Find information of the earliest flight from Singapore Changi Airport to Tokyo Haneda Airport for 25 November 2022

# %%
cursor = db.Flight.aggregate([
    {'$match': {
            'originAirport': 'WSSS', 
            'destinationAirport': 'RJTT', 
            'departureDatetime': {
                '$gte': datetime(2022, 11, 25, 0, 0, 0, tzinfo=timezone.utc),
                '$lte': datetime(2022, 11, 26, 0, 0, 0, tzinfo=timezone.utc)
            }}
    }, {'$lookup': {'from': 'Airport', 'localField': 'originAirport', 'foreignField': '_id', 'as': 'origin'}
    }, {'$lookup': {'from': 'Airport', 'localField': 'destinationAirport', 'foreignField': '_id', 'as': 'destination'}
    }, {'$unwind': {'path': '$origin'}
    }, {'$unwind': {'path': '$destination', }
    }, {'$project': {
            '_id': 0, 
            'origin.iata': 1, 
            'origin.airportName': 1, 
            'destination.iata': 1, 
            'destination.airportName': 1, 
            'departureDatetime': 1, 
            'arrivalDatetime': 1, 
            'priceUSD': 1
        }
    },
    {'$sort': {'departureDatetime': 1}},
    {'$limit': 1}
])

for idx, doc in enumerate(cursor):
    print(str(idx) + ": ", end="")
    pprint(doc, indent=2)
    print()
# Out:
# 0: { 'arrivalDatetime': datetime.datetime(2022, 11, 25, 8, 19),
#   'departureDatetime': datetime.datetime(2022, 11, 25, 1, 45),
#   'destination': { 'airportName': 'Tokyo Haneda International Airport',
#                    'iata': 'HND'},
#   'origin': {'airportName': 'Singapore Changi Airport', 'iata': 'SIN'},
#   'priceUSD': 1934.94}

# %% [markdown]
# ## Query 5 - Get the ticket information of flight tickets that the user "bubuding" has bought, for flights in the month of Nov 2022. ("bubuding" has a _id of "cl92lvec40000obt1t62zu8ca")

# %%
cursor = db.User.aggregate([
    {'$match': {'_id': 'cl92lvec40000obt1t62zu8ca'}},
    {'$unwind': {'path': '$tickets'}}, 
    {'$replaceRoot': {'newRoot': '$tickets'}},
    {'$lookup': {'from': 'Flight', 'localField': 'flight', 'foreignField': '_id', 'as': 'flight'}},
    {'$lookup': {'from': 'Passenger', 'localField': 'passenger', 'foreignField': '_id', 'as': 'passenger'}}, 
    {'$unwind': {'path': '$flight'}},
    {'$unwind': {'path': '$passenger'}},
    {'$match': {'flight.departureDatetime': {
                '$gte': datetime(2022, 11, 1, 0, 0, 0, tzinfo=timezone.utc), 
                '$lt': datetime(2022, 12, 1, 0, 0, 0, tzinfo=timezone.utc)}}
    }, 
    {'$sort': {'flight.departureDatetime': 1}}
])

for idx, doc in enumerate(cursor):
  print(str(idx) + ": ", end="")
  pprint(doc, indent=2)
  print()
# Out:
# 0: { 'class': 'First',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 852000),
#   'flight': { '_id': ObjectId('63712fba1a04abd973e87ff4'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 5, 3, 58),
#               'balanceCapacity': 151,
#               'departureDatetime': datetime.datetime(2022, 11, 4, 10, 15),
#               'destinationAirport': 'SCCI',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('637130401a04abd973f43e87')],
#               'priceUSD': 6193.13,
#               'totalCapacity': 152},
#   'passenger': { '_id': ObjectId('637130401a04abd973f43e87'),
#                  'age': 50,
#                  'firstName': 'Matthew',
#                  'flights': [ObjectId('63712fba1a04abd973e87ff4')],
#                  'lastName': 'Watson',
#                  'nationality': 'MYS',
#                  'passportNumber': 'T7524510Y',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '1B',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 852000)}
#
# 1: { 'class': 'Economy',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 795000),
#   'flight': { '_id': ObjectId('63712fb91a04abd973dc379a'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 6, 15, 28),
#               'balanceCapacity': 215,
#               'departureDatetime': datetime.datetime(2022, 11, 5, 20, 45),
#               'destinationAirport': 'KRME',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('637130401a04abd973f43e86')],
#               'priceUSD': 6991.63,
#               'totalCapacity': 216},
#   'passenger': { '_id': ObjectId('637130401a04abd973f43e86'),
#                  'age': 63,
#                  'firstName': 'Jasmine',
#                  'flights': [ObjectId('63712fb91a04abd973dc379a')],
#                  'lastName': 'Horn',
#                  'nationality': 'RWA',
#                  'passportNumber': 'U5962547U',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '24D',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 795000)}
#
# 2: { 'class': 'First',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 96000),
#   'flight': { '_id': ObjectId('63712fb71a04abd973d06294'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 8, 2, 52),
#               'balanceCapacity': 190,
#               'departureDatetime': datetime.datetime(2022, 11, 7, 14, 15),
#               'destinationAirport': 'ETHC',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('637130401a04abd973f43e7a')],
#               'priceUSD': 3733.92,
#               'totalCapacity': 191},
#   'passenger': { '_id': ObjectId('637130401a04abd973f43e7a'),
#                  'age': 43,
#                  'firstName': 'Julia',
#                  'flights': [ObjectId('63712fb71a04abd973d06294')],
#                  'lastName': 'Byrd',
#                  'nationality': 'ZMB',
#                  'passportNumber': 'A2656567I',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '2B',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 96000)}
#
# 3: { 'class': 'Business',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 565000),
#   'flight': { '_id': ObjectId('63712fba1a04abd973e944ee'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 9, 11, 19),
#               'balanceCapacity': 227,
#               'departureDatetime': datetime.datetime(2022, 11, 8, 11, 15),
#               'destinationAirport': 'SKGI',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('6371303f1a04abd973f43e70')],
#               'priceUSD': 8008.35,
#               'totalCapacity': 228},
#   'passenger': { '_id': ObjectId('6371303f1a04abd973f43e70'),
#                  'age': 44,
#                  'firstName': 'Justin',
#                  'flights': [ObjectId('63712fba1a04abd973e944ee')],
#                  'lastName': 'Jackson',
#                  'nationality': 'IND',
#                  'passportNumber': 'H4551753Y',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '6F',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 565000)}
#
# 4: { 'class': 'Business',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 351000),
#   'flight': { '_id': ObjectId('63712fbd1a04abd973f3c8a0'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 14, 8, 16),
#               'balanceCapacity': 218,
#               'departureDatetime': datetime.datetime(2022, 11, 14, 4, 15),
#               'destinationAirport': 'ZUUU',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('637130401a04abd973f43e7f')],
#               'priceUSD': 1221.39,
#               'totalCapacity': 219},
#   'passenger': { '_id': ObjectId('637130401a04abd973f43e7f'),
#                  'age': 49,
#                  'firstName': 'Felicia',
#                  'flights': [ObjectId('63712fbd1a04abd973f3c8a0')],
#                  'lastName': 'Pennington',
#                  'nationality': 'ECU',
#                  'passportNumber': 'L8059441R',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '10A',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 351000)}
#
# 5: { 'class': 'Business',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 720000),
#   'flight': { '_id': ObjectId('63712fb71a04abd973d7f1e0'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 20, 12, 56),
#               'balanceCapacity': 203,
#               'departureDatetime': datetime.datetime(2022, 11, 19, 18, 0),
#               'destinationAirport': 'KGUS',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('6371303f1a04abd973f43e73')],
#               'priceUSD': 7695.48,
#               'totalCapacity': 204},
#   'passenger': { '_id': ObjectId('6371303f1a04abd973f43e73'),
#                  'age': 66,
#                  'firstName': 'Gerald',
#                  'flights': [ObjectId('63712fb71a04abd973d7f1e0')],
#                  'lastName': 'Johnson',
#                  'nationality': 'PNG',
#                  'passportNumber': 'A2456636G',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '6B',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 720000)}
#
# 6: { 'class': 'Economy',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 995000),
#   'flight': { '_id': ObjectId('63712fb71a04abd973d10ba4'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 21, 0, 37),
#               'balanceCapacity': 202,
#               'departureDatetime': datetime.datetime(2022, 11, 20, 12, 45),
#               'destinationAirport': 'FCOI',
#               'originAirport': 'WSSS',
#               'passengers': [ObjectId('6371303f1a04abd973f43e78')],
#               'priceUSD': 4262.62,
#               'totalCapacity': 203},
#   'passenger': { '_id': ObjectId('6371303f1a04abd973f43e78'),
#                  'age': 36,
#                  'firstName': 'Jeremy',
#                  'flights': [ObjectId('63712fb71a04abd973d10ba4')],
#                  'lastName': 'Rhodes',
#                  'nationality': 'TUN',
#                  'passportNumber': 'Q7869436X',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '23G',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 23, 995000)}
#
# 7: { 'class': 'Economy',
#   'createdAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 994000),
#   'flight': { '_id': ObjectId('63712fb91a04abd973e1402d'),
#               'arrivalDatetime': datetime.datetime(2022, 11, 25, 0, 34),
#               'balanceCapacity': 202,
#               'departureDatetime': datetime.datetime(2022, 11, 24, 14, 30),
#               'destinationAirport': 'WSSS',
#               'originAirport': 'LTAP',
#               'passengers': [ObjectId('637130401a04abd973f43e89')],
#               'priceUSD': 3921.92,
#               'totalCapacity': 203},
#   'passenger': { '_id': ObjectId('637130401a04abd973f43e89'),
#                  'age': 64,
#                  'firstName': 'Debra',
#                  'flights': [ObjectId('63712fb91a04abd973e1402d')],
#                  'lastName': 'Sims',
#                  'nationality': 'GAB',
#                  'passportNumber': 'O6443711F',
#                  'user': 'cl92lvec40000obt1t62zu8ca'},
#   'seat': '24D',
#   'updatedAt': datetime.datetime(2022, 11, 14, 1, 58, 24, 994000)}
